# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
import scipy 
from scipy import stats

# %%
data = pd.read_csv(r'C:\Users\Faiq Hilman\Downloads\censusCrimeClean.csv')

# %%
data
# Out:
#             communityname  fold  population  householdsize  racepctblack  \
# 0            Lakewoodcity     1        0.19           0.33          0.02
# 1             Tukwilacity     1        0.00           0.16          0.12
# 2            Aberdeentown     1        0.00           0.42          0.49
# 3     Willingborotownship     1        0.04           0.77          1.00
# 4       Bethlehemtownship     1        0.01           0.55          0.02
# ...                   ...   ...         ...            ...           ...
# 1989    TempleTerracecity    10        0.01           0.40          0.10
# 1990          Seasidecity    10        0.05           0.96          0.46
# 1991        Waterburytown    10        0.16           0.37          0.25
# 1992          Walthamcity    10        0.08           0.51          0.06
# 1993          Ontariocity    10        0.20           0.78          0.14
#
#       racePctWhite  racePctAsian  racePctHisp  agePct12t21  agePct12t29  ...  \
# ...

# %%
a = data['medIncome']
b = data['ViolentCrimesPerPop']
p_value = scipy.stats.pearsonr(a,b)
s_value = scipy.stats.spearmanr(a,b)
print(p_value)
print(s_value)
data.plot.scatter(x='medIncome',y='ViolentCrimesPerPop',color = 'purple')
plt.show()
# Out:
# (-0.42422061672612743, 6.334424808041331e-88)
# SpearmanrResult(correlation=-0.482169950997556, pvalue=1.2978853095169542e-116)

# %%
a = data['blackPerCap']
b = data['ViolentCrimesPerPop']
p_value = scipy.stats.pearsonr(a,b)
s_value = scipy.stats.spearmanr(a,b)
print(p_value)
print(s_value)
data.plot.scatter(x='blackPerCap',y='ViolentCrimesPerPop',color = 'purple')
plt.show()
# Out:
# (-0.27539108571388604, 4.94012344488263e-36)
# SpearmanrResult(correlation=-0.31135356737038017, pvalue=4.469108862544648e-46)

# %%
a = data['AsianPerCap']
b = data['ViolentCrimesPerPop']
p_value = scipy.stats.pearsonr(a,b)
s_value = scipy.stats.spearmanr(a,b)
print(p_value)
print(s_value)
data.plot.scatter(x='medIncome',y='ViolentCrimesPerPop',color = 'purple')
plt.show()
# Out:
# (-0.15559166472730754, 2.827252645622553e-12)
# SpearmanrResult(correlation=-0.20790184002873874, pvalue=6.5628567752630906e-21)

# %%
data2 = pd.read_csv(r'C:\Users\Faiq Hilman\Downloads\heart.csv')
data2
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
data2["gender"] = np.where(abs(data2.sex) == 0,0,1)
data2["hasHeartDisease"] = np.where(abs(data2.target)==0,1,0)
print(data2)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target  gender  hasHeartDisease
# ...

# %%
restmean = np.mean(data2.trestbps)
restsd = np.std(data2.trestbps)
print("mean is", restmean)
print("stdev is", restsd)
# Out:
# mean is 131.62376237623764
# stdev is 17.509178065734385

# %%
WD = data2.trestbps.loc[data2.hasHeartDisease==1]
WDmean = np.mean(WD)
WDstd = np.std(WD)
ND = data2.trestbps.loc[data2.hasHeartDisease==0]
NDmean = np.mean(ND)
NDstd = np.std(ND)
print("Mean and Stdev with diseases", WDmean,WDstd)
print("Mean and Stdev without disease",NDmean,NDstd)
# Out:
# Mean and Stdev with diseases 134.3985507246377 18.66195845970553
# Mean and Stdev without disease 129.3030303030303 16.120539972317363

# %%
fig, axs = plt.subplots(ncols=2,sharey=True)
axs[0].boxplot(WD, vert=False)
axs[0].set_title('Disease')
axs[1].boxplot(ND, vert=False)
axs[1].set_title('No disease')
# Out:
# Text(0.5, 1.0, 'No disease')

# %%
fig, axs = plt.subplots(ncols = 2, sharey=True)
axs[0].hist(WD,color = 'purple')
axs[0].set_title('Disease')
axs[1].hist(ND, color = 'gold')
axs[1].set_title('No disease')
# Out:
# Text(0.5, 1.0, 'No disease')

# %%
a = WD
b = ND
ttest = scipy.stats.ttest_ind(a,b)
print(ttest)
# Out:
# Ttest_indResult(statistic=2.5412927171039, pvalue=0.011546059200233312)

# %%
u1 = np.mean(WD)
u2 = np.mean(ND)
print(u1)
print(u2)
# Out:
# 134.3985507246377
# 129.3030303030303

# %%
n1, n2 = len(ND), len(WD)
print(n1)
print(n2)
# Out:
# 165
# 138

# %%
from numpy.random import randn
from numpy.random import seed
from numpy import mean
from numpy import var
from math import sqrt

def cohend(WD, ND):
	# calculate the size of samples
	n1, n2 = len(WD), len(ND)
	# calculate the variance of the samples
	s1, s2 = var(WD, ddof=1), var(ND, ddof=1)
	# calculate the pooled standard deviation
	s = sqrt(((n1 - 1) * s1 + (n2 - 1) * s2) / (n1 + n2 - 2))
	# calculate the means of the samples
	u1, u2 = mean(WD), mean(ND)
	# calculate the effect size
	return (u1 - u2) / s

# %%
#Count the number with the disease for each gender type
hasDiseaseCount=data[data.hasHeartDisease==True].groupby('gender').count().hasHeartDisease

#Count the number of gender type
totalCount=data.groupby("gender").count()['hasHeartDisease']

#combine into a dataframe (both are indexed with gender, so will be matched) and specify the columns
p=pd.concat([hasDiseaseCount, totalCount], axis=1)
p.columns = ["heartDiseaseCount", "totalCount"]

#create a new column and calculate the proportion
p['propHeartDisease']=p["heartDiseaseCount"]/p["totalCount"]

#print the results
print(p.head())
# Out:
#   File "<ipython-input-100-a565a1ee1b74>", line 2
#     hasDiseaseCount=data[data.hasHeartDisease==True].groupby('gender').count().'hasHeartDisease'
#                                                                                                ^
# SyntaxError: invalid syntax
